# %% [markdown]
# ## Carolyn Randall - Homework 3 - Project part
# **Course Project**
# *Share with a me a ipython notebook containing the following:
# * Data read into python in a data frame
#
# * A statistical summary of your data
# * A visualisation of your data
# * One of the following with your data; Linear or Logistic Regression (with regularization), or Clustering.
# * A written summary at the end describing your data

# %% [markdown]
# ## Things I need assistance with
# ####  I am struggling to know what models to use to answer my questions
# #### I was unable to show a nice linear line with data, so maybe I used the wrong features?
# #### Or is it because this data doesn't suit linear regression?
# ####  The panda profile report showed G2 highly correlated with G3 - rejected, so does that mean not significant to use?
# #### I was wondering if it was possible to show a decision tree, just as supplementary information for my presentation, but was getting errors trying to do this
# ####  My main issue is I am not understanding well enough when to use the dummies vs. numeric data

# %% [markdown]
# ### Project questions to try and answer
# #### I combined the data (Math and Portuguese) into one file and I am looking at the final grades G3.  I decided  to answer questions on all grades rather than analysis Math vs. Portuguese. I may include a comparison to Math and Portuguese but that is not my focusI instead will look at the differences between the two schools
# * What factors influence the final grade G3? (or I can average all 3 as you suggest Ian), the panda profile report showed G2 highly correlated with G3 - rejected
# * What factors are the same in predicting the performance of students test scores based on which school they attend
# * What factors are different in predicting the performance of students test scores based on the school they attend
# * How could someone improve their test score?

# %% [markdown]
# ### Data Description
# Below is a description of what the headings and the values in these fields means
# * school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# * sex - student's sex (binary: 'F' - female or 'M' - male)
# * age - student's age (numeric: from 15 to 22)
# * address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# * Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# * Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * traveltime - home to school travel time (numeric: 1 - 1 hour)
# * studytime - weekly study time (numeric: 1 - 10 hours)
# * failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * schoolsup - extra educational support (binary: yes or no)
# * famsup - family educational support (binary: yes or no)
# * paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * activities - extra-curricular activities (binary: yes or no)
# * nursery - attended nursery school (binary: yes or no)
# * higher - wants to take higher education (binary: yes or no)
# * internet - Internet access at home (binary: yes or no)
# * romantic - with a romantic relationship (binary: yes or no)
# * famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * health - current health status (numeric: from 1 - very bad to 5 - very good) 30. absences - number of school absences (numeric: from 0 to 93)
# These grades are related with the course subject, Math or Portuguese:
# 1.    G1 - first period grade (numeric: from 0 to 20)
# 2.    G2 - second period grade (numeric: from 0 to 20)
# 3.    G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## STEP 1 - Read  the data

# %%
# import some libraries
import pandas as pd
import numpy as np

# %%
# Data csv files downloaded from Kaggle.  
# Let's read the student maths data set into a Dataframe called 'studentmath
studentmath = pd.read_csv('student-mat.csv')  
# read the student portuguese data into a Dataframe called 'studentport'
studentport = pd.read_csv('student-por.csv')

# %% [markdown]
#  I am going to merge the two files so I have a larger set of data to use and not sure yet
#  if the subject is significant until I do some modeling
#  But, before I merge I will add a column to each dataset to identify the subject the grades G1, G2 and G3 are associated with
#
# #### * subject=M for math or
# #### * subject = P for Portuguese

# %%
studentmath['subject'] = 'M'

# %%
# check the head to see the new column has been added
studentmath.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
studentport['subject'] = 'P'

# %%
studentport.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#     ...   freetime goout  Dalc  Walc  health absences  G1  G2  G3 subject
# 0   ...          3     4     1     1       3        4   0  11  11       P
# 1   ...          3     3     1     1       3        2   9  11  11       P
# 2   ...          3     2     2     3       3        6  12  13  12       P
# 3   ...          2     2     1     1       5        0  14  14  14       P
# 4   ...          3     2     1     2       5        0  11  13  13       P
#
# [5 rows x 34 columns]

# %%
# see how many records in the math data set
len(studentmath)
# Out:
# 395

# %%
# see how many records are in the portuguese data set
len(studentport)
# Out:
# 649

# %%
# check the columns in each dataset before we merge to make sure they are the same
studentport.columns == studentmath.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
# now merge the two data sets
studentsall=pd.merge(studentmath, studentport, how='outer')

# %%
studentsall.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1',
#        'G2', 'G3', 'subject'], dtype=object)

# %%
# check the data
studentsall
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# 5        GP   M   16       U     LE3       T     4     3  services     other
# 6        GP   M   16       U     LE3       T     2     2     other     other
# 7        GP   F   17       U     GT3       A     4     4     other   teacher
# 8        GP   M   15       U     LE3       A     3     2  services     other
# 9        GP   M   15       U     GT3       T     3     4     other     other
# 10       GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
studentsall

# %%
# double check the merge includes all the data should be 395 + 649=1044
len(studentsall)
# Out:
# 1044

# %%
# do we have any missing data?
studentsall.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# subject       0
# dtype: int64

# %%
studentsall.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# subject       object
# dtype: object

# %%
# found these functions on kaggle so using them they look useful to see data values
def get_feature_lists_by_dtype(data):
    features = data.columns.tolist()
    output = {}
    for f in features:
        dtype = str(data[f].dtype)
        if dtype not in output.keys(): output[dtype] = [f]
        else: output[dtype] += [f]
    return output

def show_uniques(data,features):
    for f in features:
        if len(data[f].unique()) < 30:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()))
        else:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()[0:10]))
def show_all_uniques(data):
    dtypes = get_feature_lists_by_dtype(data)
    for key in dtypes.keys():
        print(key + "\n")
        show_uniques(data,dtypes[key])
        print()

# %%
# lets take a look at the unique values for each feature to get an overview of 
# what the data looks like
show_all_uniques(studentsall)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
# subject: count(2) ['M' 'P']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 2 1]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# ...

# %% [markdown]
# ## STEP 2 - Statistical Summary of Data

# %%
# use describe to get a statistical summary But note, this will only show numerical features
# About half the data is NON numeric, so keep this in mind as later if we run linear regressions
# we will have to convert the non-numeric to numeric values
studentsall.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
# Look for any linear correlations in the data
studentsall.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.130196 -0.138521    0.049216  -0.007870  0.282364
# Medu       -0.130196  1.000000  0.642063   -0.238181   0.090616 -0.187769
# Fedu       -0.138521  0.642063  1.000000   -0.196328   0.033458 -0.191390
# traveltime  0.049216 -0.238181 -0.196328    1.000000  -0.081328  0.087177
# studytime  -0.007870  0.090616  0.033458   -0.081328   1.000000 -0.152024
# failures    0.282364 -0.187769 -0.191390    0.087177  -0.152024  1.000000
# famrel      0.007162  0.015004  0.013066   -0.012578   0.012324 -0.053676
# freetime    0.002645  0.001054  0.002142   -0.007403  -0.094429  0.102679
# goout       0.118510  0.025614  0.030075    0.049740  -0.072941  0.074683
# Dalc        0.133453  0.001515 -0.000165    0.109423  -0.159665  0.116336
# Walc        0.098291 -0.029331  0.019524    0.084292  -0.229073  0.107432
# health     -0.029129 -0.013254  0.034288   -0.029002  -0.063044  0.048311
# ...

# %%
#let's do some grouping and see the stats

# %%
# Group data by school 
sorted_byschool = studentsall.groupby('school')

# %%
# summary statistics for all numeric columns by school
sorted_byschool.describe()
# provide the mean for each numeric column by school
sorted_byschool.mean()
# Out:
#               age      Medu      Fedu  traveltime  studytime  failures  \
# school
# GP      16.601036  2.760363  2.510363    1.410622   2.036269  0.238342
# MS      17.080882  2.158088  2.040441    1.841912   1.783088  0.338235
#
#           famrel  freetime     goout      Dalc      Walc    health  absences  \
# school
# GP      3.955959  3.185233  3.130829  1.458549  2.264249  3.588083  5.006477
# MS      3.878676  3.246324  3.227941  1.595588  2.341912  3.415441  2.812500
#
#                G1         G2         G3
# school
# GP      11.512953  11.528497  11.633420
# MS      10.363971  10.444853  10.514706

# %%
# Group data by paid 
sorted_bypaid = studentsall.groupby('paid')

# %%
# summary statistics for all numeric columns by paid
sorted_bypaid.describe()
# provide the mean for each numeric column by paid
sorted_bypaid.mean()
# Out:
#             age      Medu      Fedu  traveltime  studytime  failures  \
# paid
# no    16.743932  2.509709  2.320388    1.554612   1.924757  0.276699
# yes   16.659091  2.954545  2.640909    1.404545   2.140909  0.218182
#
#         famrel  freetime     goout      Dalc      Walc    health  absences  \
# paid
# no    3.928398  3.219660  3.163835  1.474515  2.256068  3.549757  4.208738
# yes   3.963636  3.131818  3.127273  1.568182  2.390909  3.518182  5.281818
#
#              G1         G2         G3
# paid
# no    11.273058  11.271845  11.440534
# yes   10.990909  11.150000  10.972727

# %%
# Group data by mother's education
sorted_byMedu = studentsall.groupby('Medu')

# %%
# Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 
#  2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)

sorted_byMedu.describe()
# provide the mean for each numeric column by Medu Mother's education
sorted_byMedu.mean()
# Out:
#             age      Fedu  traveltime  studytime  failures    famrel  \
# Medu
# 0     17.111111  1.444444    1.555556   1.666667  0.555556  3.222222
# 1     16.980198  1.396040    1.816832   1.797030  0.475248  3.900990
# 2     16.737024  1.972318    1.612457   1.996540  0.242215  3.965398
# 3     16.789916  2.584034    1.411765   2.021008  0.344538  3.991597
# 4     16.486928  3.310458    1.330065   2.029412  0.075163  3.908497
#
#       freetime     goout      Dalc      Walc    health  absences         G1  \
# Medu
# 0     3.333333  2.666667  1.666667  2.666667  4.000000  0.777778  11.222222
# 1     3.207921  3.183168  1.569307  2.450495  3.519802  3.539604  10.207921
# 2     3.179931  3.079585  1.356401  2.114187  3.584775  4.266436  10.975779
# 3     3.210084  3.201681  1.605042  2.403361  3.525210  5.848739  11.025210
# 4     3.205882  3.189542  1.483660  2.232026  3.519608  4.192810  12.248366
#
#              G2         G3
# Medu
# 0     11.666667  12.111111
# ...

# %%
# Group data by father's education
sorted_byFedu = studentsall.groupby('Fedu')

# %%
# Fedu has same numeric definitions as Medu
sorted_byFedu.describe()
# provide the mean for each numeric column by Father's eduction
sorted_byFedu.mean()
# Out:
#             age      Medu  traveltime  studytime  failures    famrel  \
# Fedu
# 0     16.777778  1.555556    2.000000   2.000000  0.222222  3.888889
# 1     17.027344  1.679688    1.792969   1.871094  0.476562  3.921875
# 2     16.694444  2.311728    1.484568   2.012346  0.277778  3.904321
# 3     16.658009  3.069264    1.372294   2.038961  0.151515  4.017316
# 4     16.495536  3.642857    1.406250   1.950893  0.120536  3.915179
#
#       freetime     goout      Dalc      Walc    health  absences         G1  \
# Fedu
# 0     3.222222  2.555556  1.000000  1.000000  3.444444  2.222222  11.555556
# 1     3.199219  3.152344  1.546875  2.335938  3.582031  3.972656  10.269531
# 2     3.225309  3.129630  1.503086  2.234568  3.500000  4.422840  11.246914
# 3     3.125541  3.164502  1.372294  2.329004  3.307359  5.090909  11.303030
# 4     3.245536  3.214286  1.566964  2.303571  3.808036  4.392857  12.138393
#
#              G2         G3
# Fedu
# 0     11.888889  12.333333
# ...

# %%
# Group data by schoolsup
sorted_bysup = studentsall.groupby('schoolsup')

# %%
sorted_bysup.describe()
# provide the mean for each numeric column by school sup
sorted_bysup.mean()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# schoolsup
# no         16.816216  2.612973  2.375135    1.531892   1.949189  0.263784
# yes        16.025210  2.529412  2.487395    1.453782   2.134454  0.268908
#
#              famrel  freetime     goout      Dalc      Walc    health  \
# schoolsup
# no         3.938378  3.210811  3.177297  1.502703  2.327568  3.542703
# yes        3.915966  3.126050  2.991597  1.428571  1.949580  3.546218
#
#            absences        G1         G2         G3
# schoolsup
# no         4.455135  11.36000  11.350270  11.451892
# yes        4.277311  10.07563  10.436975  10.487395

# %%
# Group data by daily alchol
sorted_byDalc = studentsall.groupby('Dalc')

# %%
sorted_byDalc.describe()
# provide the mean for each numeric column by daily alcohol
sorted_byDalc.mean()
# Out:
#             age      Medu      Fedu  traveltime  studytime  failures  \
# Dalc
# 1     16.661623  2.598349  2.385144    1.486933   2.061898  0.214580
# 2     16.683673  2.627551  2.392857    1.520408   1.831633  0.341837
# 3     16.985507  2.579710  2.434783    1.666667   1.594203  0.434783
# 4     17.461538  2.692308  2.346154    1.923077   1.730769  0.384615
# 5     17.423077  2.538462  2.346154    1.769231   1.692308  0.500000
#
#         famrel  freetime     goout      Walc    health  absences         G1  \
# Dalc
# 1     4.011004  3.108666  2.983494  1.763411  3.467675  3.972490  11.492435
# 2     3.698980  3.346939  3.387755  3.102041  3.688776  4.979592  10.790816
# 3     3.869565  3.478261  3.681159  3.913043  3.855072  5.782609  10.492754
# 4     3.846154  3.307692  3.769231  3.923077  3.615385  6.500000   9.884615
# 5     3.884615  3.846154  4.230769  4.730769  3.653846  7.615385   9.846154
#
#              G2         G3
# Dalc
# 1     11.536451  11.704264
# ...

# %% [markdown]
# ## STEP 3 Visualize

# %%
# Display the plots in the notebook with the following command
# Note I was not really show what data to pick for some of the graphs 
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %%
studentsall[['Medu']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f3c5cf8>]], dtype=object)

# %%
studentsall[['Fedu']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111aa22e8>]], dtype=object)

# %%
sns.distplot(studentsall.G3)
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
sns.set(color_codes=True)
# now look at a plot with G1 and WALC weekend alcohol consumption
sns.lmplot(x='G3', y="Medu", hue="G3", data=studentsall, fit_reg=True)

# %%
import seaborn as sns
sns.set(color_codes=True)
# now look at a plot with G1 and WALC weekend alcohol consumption
sns.lmplot(x='G3', y="famrel", hue="G3", data=studentsall, fit_reg=True)

# %%
# now I see about half my data is numeric and half non-numeric, so I need to convert the data 
# to numeric

from sklearn.dummy import DummyClassifier
# Convert some categorical columns to binary representations BUT some have more 2 values

students_with_dummies = pd.get_dummies(data=studentsall, columns = ['sex', 'school','activities','romantic','address', 'schoolsup','famsize', 'Pstatus', 'Mjob', 'Fjob', 'guardian', 'internet','subject','paid','reason'], prefix = ['sex', 'school','activies','romantic','address', 'schoolsup','famsize', 'Pstatus', 'Mjob', 'Fjob', 'guardian', 'internet','subject','paid','reason'] )
students_with_dummies.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures famsup nursery higher  \
# 0   18     4     4           2          2         0     no     yes    yes
# 1   17     1     1           1          2         0    yes      no    yes
# 2   15     1     1           1          2         3     no     yes    yes
# 3   15     4     2           1          3         0    yes     yes    yes
# 4   16     3     3           1          2         0    yes     yes    yes
#
#    famrel        ...          internet_no  internet_yes  subject_M  subject_P  \
# 0       4        ...                    1             0          1          0
# 1       5        ...                    0             1          1          0
# 2       4        ...                    0             1          1          0
# 3       3        ...                    0             1          1          0
# 4       4        ...                    1             0          1          0
#
# ...

# %%
students_with_dummies.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famsup',
#        'nursery', 'higher', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3', 'sex_F', 'sex_M', 'school_GP',
#        'school_MS', 'activies_no', 'activies_yes', 'romantic_no',
#        'romantic_yes', 'address_R', 'address_U', 'schoolsup_no',
#        'schoolsup_yes', 'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'guardian_father', 'guardian_mother',
#        'guardian_other', 'internet_no', 'internet_yes', 'subject_M',
#        'subject_P', 'paid_no', 'paid_yes', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation'],
#       dtype='object')

# %%
#Plot a Correlation Matrix with extra data
corr = students_with_dummies.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                         age      Medu      Fedu  traveltime  studytime  \
# age                1.000000 -0.130196 -0.138521    0.049216  -0.007870
# Medu              -0.130196  1.000000  0.642063   -0.238181   0.090616
# Fedu              -0.138521  0.642063  1.000000   -0.196328   0.033458
# traveltime         0.049216 -0.238181 -0.196328    1.000000  -0.081328
# studytime         -0.007870  0.090616  0.033458   -0.081328   1.000000
# failures           0.282364 -0.187769 -0.191390    0.087177  -0.152024
# famrel             0.007162  0.015004  0.013066   -0.012578   0.012324
# freetime           0.002645  0.001054  0.002142   -0.007403  -0.094429
# goout              0.118510  0.025614  0.030075    0.049740  -0.072941
# Dalc               0.133453  0.001515 -0.000165    0.109423  -0.159665
# Walc               0.098291 -0.029331  0.019524    0.084292  -0.229073
# health            -0.029129 -0.013254  0.034288   -0.029002  -0.063044
# ...

# %%
# Let's make that plot a bit larger
plt.figure(figsize = (20,20))
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')

# %%
#Extract ''G3'' column, because 'G3' is our target value
corr_left = pd.DataFrame(corr['G3'].drop('G3'))
corr_left.sort_values(by = 'G3', ascending = False)
# Out:
#                          G3
# G2                 0.910743
# G1                 0.809142
# Medu               0.201472
# subject_P          0.187166
# studytime          0.161629
# Fedu               0.159796
# school_GP          0.127114
# reason_reputation  0.121303
# address_U          0.117696
# internet_yes       0.107064
# Fjob_teacher       0.101361
# Mjob_health        0.101349
# romantic_no        0.098363
# Mjob_teacher       0.084521
# schoolsup_no       0.079346
# famsize_LE3        0.061209
# famrel             0.054461
# paid_no            0.049388
# Mjob_services      0.045015
# guardian_father    0.042778
# Fjob_health        0.042101
# activies_yes       0.033998
# sex_F              0.031472
# Pstatus_A          0.030693
# guardian_mother    0.009746
# reason_home        0.003895
# Fjob_at_home      -0.021194
# Fjob_other        -0.023825
# Pstatus_T         -0.030693
# sex_M             -0.031472
# activies_no       -0.033998
# Fjob_services     -0.035273
# ...

# %%
# if you xx
plt.figure(figsize = (10,6))
sns.barplot(x='activies_yes', y = 'G3', hue = 'sex_F', data = students_with_dummies)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='school_GP', y = 'G3', hue = 'school_MS', data = students_with_dummies)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='subject_M', y = 'G3', hue = 'subject_P', data = students_with_dummies)

# %%
# take a look at mother's education
plt.figure(figsize = (10,6))
sns.barplot(x='Medu', y = 'G3', hue = 'sex_F', data = students_with_dummies)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='Dalc', y = 'G3', hue = 'sex_F', data = students_with_dummies)

# %%
# take a look at 
plt.figure(figsize = (10,6))
sns.barplot(x='studytime', y = 'G3', hue = 'sex_F', data = students_with_dummies)

# %%
import pandas_profiling
#pandas_profiling.ProfileReport(studentsall)
pandas_profiling.ProfileReport(students_with_dummies)
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
# ...

# %% [markdown]
# ## STEP 4 Modelling

# %%
# I require some assistance with knowing what models to apply and whether or not if I use dummy
# values for features that have several possible values if that can distort predictions??

# %%
# create a fitted model in one line
import seaborn as sns
sns.set_style("darkgrid")
# this allows plots to appear directly in the notebook
# %matplotlib inline
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula='G3 ~ Medu + studytime', data=students_with_dummies).fit()
# print the coefficients!
lm.params
# Out:
# Intercept    8.337707
# Medu         0.647183
# studytime    0.669611
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G3   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     34.00
# Date:                Sun, 09 Jul 2017   Prob (F-statistic):           4.97e-15
# Time:                        11:34:32   Log-Likelihood:                -2859.2
# No. Observations:                1044   AIC:                             5724.
# Df Residuals:                    1041   BIC:                             5739.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      8.3377      0.385     21.638      0.000         7.582     9.094
# ...

# %%
lm = smf.ols(formula='G3 ~ Medu + studytime + Mjob_teacher', data=students_with_dummies).fit()
# print the coefficients!
lm.params
# Out:
# Intercept       8.326280
# Medu            0.654558
# studytime       0.669156
# Mjob_teacher   -0.055215
# dtype: float64

# %%
#would like to see the average grade for G3
#students_with_dummies.G3.avg()
np.mean(students_with_dummies.G3)
# Out:
# 11.341954022988507

# %%
## lets focus over support for education now from parents / school
## using Pstatus field here to show impact of this over performance
## Pstatus = A indicates parents apart
## Pstatus = T indicates parents together

fig, ax = plt.subplots(1, 2)

student_df = students_with_dummies[['Pstatus_A', 'Pstatus_T','studytime','Medu']]
student_df_A = student_df[student_df['Pstatus_A'] == 1]
student_df_A.groupby(['Pstatus_A', 'Medu']).sum().plot(ax=ax[0], title="Pstatus vs studytime vs Medu")

student_df_T = student_df[student_df['Pstatus_T'] == 1]
student_df_T.groupby(['Pstatus_T', 'Medu']).sum().plot(ax=ax[1], title="Pstatus vs studytime vs Medu")

# %%
# Look at parent education and job as a teacher

fig, ax = plt.subplots(1, 2)

parent_t = students_with_dummies[['Mjob_teacher','Medu','Fjob_teacher', 'Fedu']]
parent_t_A = parent_t[parent_t['Mjob_teacher'] == 1]
parent_t_A.groupby(['Mjob_teacher', 'Medu']).sum().plot(ax=ax[0], title="Motherteacher vs edu")

parent_t_B = parent_t[parent_t['Fjob_teacher'] == 1]
parent_t_B.groupby(['Fjob_teacher','Fedu']).sum().plot(ax=ax[1], title="FatherTeacher vs Medu")

# %%
## Take a look at grades and education level of Mother and Father

fig, ax = plt.subplots(1, 2)

student_Medu = studentsall[['Medu', 'G1', 'G2', 'G3']]
student_Medu.groupby(['Medu']).sum().plot(ax=ax[0], legend=True, title="Medu vs grades")

student_Fedu = studentsall[['Fedu', 'G1', 'G2', 'G3']]
student_Fedu.groupby(['Fedu']).sum().plot(ax=ax[1], legend=True, title="Fedu vs grades")

# %%
#  split the data into training and testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#  fit a logistic regression model and examine the coefficients
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
zip(feature_cols, logreg.coef_[0])
print(logreg.fit(X_train, y_train))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_class = logreg.predict(X_test)
#print ...
from sklearn import metrics
print (metrics.accuracy_score(y_test, y_pred_class))
# Out:
# 0.168582375479

# %% [markdown]
# ### Summary of the data
# *  I combined two data files, both having the same features
# * The data consists of numeric and binary features
#
# **Some initial observations to be confirmed with analysis**
# *  Neither data set had any null values BUT I noticed that for education, a value of 0, is none, but thinking that 0 might also be unknown, but that is to be looked at
# * The mother and father's education levels seem to contribute to grades
# * Job of teacher for one or more of the parents may contibute to grades
# * There may be some significance with the school and the Math vs. Portuguese grades
# * Having internet access looks like it may be a factor in grades
# * Not sure how much impact alcohol either daily or weekly has on grades - will see when I analyze

# %% [markdown]
# ### Data Description
# Below is a description of what the headings and the values in these fields means
# * school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# * sex - student's sex (binary: 'F' - female or 'M' - male)
# * age - student's age (numeric: from 15 to 22)
# * address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# * Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# * Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * traveltime - home to school travel time (numeric: 1 - 1 hour)
# * studytime - weekly study time (numeric: 1 - 10 hours)
# * failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * schoolsup - extra educational support (binary: yes or no)
# * famsup - family educational support (binary: yes or no)
# * paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * activities - extra-curricular activities (binary: yes or no)
# * nursery - attended nursery school (binary: yes or no)
# * higher - wants to take higher education (binary: yes or no)
# * internet - Internet access at home (binary: yes or no)
# * romantic - with a romantic relationship (binary: yes or no)
# * famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * health - current health status (numeric: from 1 - very bad to 5 - very good) 30. absences - number of school absences (numeric: from 0 to 93)
# These grades are related with the course subject, Math or Portuguese:
# 1.    G1 - first period grade (numeric: from 0 to 20)
# 2.    G2 - second period grade (numeric: from 0 to 20)
# 3.    G3 - final grade (numeric: from 0 to 20, output target)
