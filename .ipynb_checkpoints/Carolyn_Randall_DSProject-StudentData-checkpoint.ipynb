# %% [markdown]
# #  Carolyn Randall - Data Science project
# ## Student Grades Datasets

# %% [markdown]
# ## A look at two datasets that included  data collected using school reports and questionnaires
#
# ### The Data attributes include student grades, demographic, social and school related featuresadd an intro here

# %% [markdown]
# ## Summary
# ### The aim is to try and see if we can find things that influence the grades for math and portuguese

# %% [markdown]
# ### Import libraries

# %%
#  import libraries
import pandas as pd
import numpy as np
from sklearn.dummy import DummyClassifier
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import pandas_profiling
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# ### Read in the 2 datasets
# #### **student-mat.csv contains student grades for a math class
# #### **student-por.csv contains student grades for a Portuguese language class

# %%
# Read the data sets into Dataframes
# Data source are csv files downloaded from Kaggle.  

# Let's read the student maths data set into a Dataframe called 'studentmath
studentmath = pd.read_csv('student-mat.csv')  

# read the student portuguese class dataset into a Dataframe called 'studentport'
studentport = pd.read_csv('student-por.csv')

# %% [markdown]
# ## Explore the data

# %% [markdown]
# ### Definitions of the data and what the values mean
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# 2.	sex - student's sex (binary: 'F' - female or 'M' - male)
#
# 3.	age - student's age (numeric: from 15 to 22)
#
# 4.	address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# 5.	famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# 6.	Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# 7.	Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade) 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8.	Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9.	Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10.	Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services'(e.g. administrative or police), 'at_home' or 'other')
# 11.	reason - reason to choose this school (nominal: close to 'home', school 'reputation','course' preference or 'other')
# 12.	guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13.	traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min. 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14.	studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15.	failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16.	schoolsup - extra educational support (binary: yes or no)
# 17.	famsup - family educational support (binary: yes or no)
# 18.	paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19.	activities - extra-curricular activities (binary: yes or no)
# 20.	nursery - attended nursery school (binary: yes or no)
# 21.	higher - wants to take higher education (binary: yes or no)
# 22.	internet - Internet access at home (binary: yes or no)
# 23.	romantic - with a romantic relationship (binary: yes or no)
# 24.	famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25.	freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26.	goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27.	Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28.	Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29.	health - current health status (numeric: from 1 - very bad to 5 - very good)	30.	absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
# 	1.	G1 - first period grade (numeric: from 0 to 20)
# 	2.	G2 - second period grade (numeric: from 0 to 20)
# 	3.	G3 - final grade (numeric: from 0 to 20, output target)

# %%
# take a quick look at the data using head function
studentmath.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
studentport.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# let's see how many rows and columns we have
studentmath.shape
# Out:
# (395, 33)

# %%
studentport.shape
# Out:
# (649, 33)

# %%
# Use describe to take another look at some statistics
# This only summarizes the numeric data
studentmath.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
# Use describe to take another look at some statistics
# This only summarizes the numeric data
studentport.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
pandas_profiling.ProfileReport(studentmath)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>33 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>395 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>101.9 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>264.2 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>G2</code> has 13 / 3.3% zeros</l><li><code>G3</code> is highly correlated with <code>G2</code> (ρ = 0.90487) <span class="label label-primary">Rejected</span></l><li><code>absences</code> has 115 / 29.1% zeros</l><li><code>failures</code> has 312 / 79.0% zeros</l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">Dalc<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>5</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>1.3%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (n)</th>
#                     <td>0</td>
#                 </tr>
#             </table>
#
#         </div>
#         <div class="col-sm-6">
#             <table class="stats ">
#
#                 <

# %%
pandas_profiling.ProfileReport(studentport)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>33 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>649 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>167.4 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>264.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>Fedu</code> has 7 / 1.1% zeros</l><li><code>G2</code> has 7 / 1.1% zeros</l><li><code>G3</code> is highly correlated with <code>G2</code> (ρ = 0.91855) <span class="label label-primary">Rejected</span></l><li><code>absences</code> has 244 / 37.6% zeros</l><li><code>failures</code> has 549 / 84.6% zeros</l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">Dalc<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>5</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>0.8%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (n)</th>
#                     <td>0</td>
#                 </tr>
#             </table>
#
#         </div>
#         <div class="col-sm-6">

# %%
# found these functions on kaggle so using them they look useful to see data types and values
def get_feature_lists_by_dtype(data):
    features = data.columns.tolist()
    output = {}
    for f in features:
        dtype = str(data[f].dtype)
        if dtype not in output.keys(): output[dtype] = [f]
        else: output[dtype] += [f]
    return output

def show_uniques(data,features):
    for f in features:
        if len(data[f].unique()) < 30:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()))
        else:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()[0:10]))
def show_all_uniques(data):
    dtypes = get_feature_lists_by_dtype(data)
    for key in dtypes.keys():
        print(key + "\n")
        show_uniques(data,dtypes[key])
        print()

# %%
show_all_uniques(studentmath)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 2 1]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# Walc: count(5) [1 3 2 4 5]
# health: count(5) [3 5 1 2 4]
# absences: count(34) [ 6  4 10  2  0 16 14  7  8 25]
# G1: count(17) [ 5  7 15  6 12 16 14 10 13  8 11  9 17 19 18  4  3]
# G2: count(17) [ 6  5  8 14 10 15 12 18 16 13  9 11  7 19 17  4  0]
# G3: count(18) [ 6 10 15 11 19  9 12 14 16  5  8 17 18 13 20  7  0  4]

# %%
show_all_uniques(studentport)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 1 2]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# Walc: count(5) [1 3 2 4 5]
# health: count(5) [3 5 1 2 4]
# absences: count(24) [ 4  2  6  0 10  8 16 14  1 12 24 22 32 30 21 15  9 18 26  7 11  5 13  3]
# G1: count(17) [ 0  9 12 14 11 13 10 15 17  8 16 18  7  6  5  4 19]
# G2: count(16) [11 13 14 12 16 17  8 10 15  9  7  6 18 19  0  5]
# G3: count(17) [11 12 14 13 17 15  7 10 16  9  8 18  6  0  1  5 19]

# %%
# lets make sure we have the same features in both data sets
studentport.columns == studentmath.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True], dtype=bool)

# %%
# let's check if the datasets have any missing data
studentmath.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# let's check if the datasets have any missing data
studentport.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ### Math Data

# %%
#  I am going to use the average of the three grades in my modeling
# I will take the average of G1, G2 and G3 
# Reminder G1 - first period grade (numeric: from 0 to 20)
#          G2 - second period grade (numeric: from 0 to 20)
#          G3 - final grade (numeric: from 0 to 20, output target)
#
studentmath['Average'] = ((studentmath.G1 + studentmath.G2 + studentmath.G3)/3)

# also store a rounded version of Average in case we need it for graphs or visuals
studentmath['roundedAvg'] = round(studentmath.Average, 0)

# %%
#now drop the original three so we don't include them in the modelling
# by mistake and keep the averages in the dataframe
# we will drop rounded before we do any modelling
studentmath = studentmath.drop('G1',axis=1)
studentmath = studentmath.drop('G2',axis=1)
studentmath = studentmath.drop('G3',axis=1)

# %%
#studentmath['roundedAvg'] = round(studentmath.Average, 0)
show_all_uniques(studentmath)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 2 1]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# Walc: count(5) [1 3 2 4 5]
# health: count(5) [3 5 1 2 4]
# absences: count(34) [ 6  4 10  2  0 16 14  7  8 25]
#
# float64
#
# Average: count(54) [  5.66666667   5.33333333   8.33333333  14.66666667   8.66666667  15.
#   11.66666667  17.66666667   9.          11.33333333]
# roundedAvg: count(19) [  6.   5.   8.  15.   9.  12.  18.  11.  14.  10.  13.  17.  16.   7.  19.
#    4.   3.   1.   2.]

# %% [markdown]
# ### Portuguese Data

# %%
# Now do the same for the Portuguese data set
#  Take the average of G1, G2 and G3 grades
# I will take the average of G1, G2 and G3 
# Reminder G1 - first period grade (numeric: from 0 to 20)
#          G2 - second period grade (numeric: from 0 to 20)
#          G3 - final grade (numeric: from 0 to 20, output target)
studentport['Average'] = ((studentport.G1 + studentport.G2 + studentport.G3)/3)

# also store a rounded version of Average in case we need it for graphs or visuals
studentport['roundedAvg'] = round(studentport.Average, 0)

# %%
#now drop the original three and keep the average
studentport = studentport.drop('G1',axis=1)
studentport = studentport.drop('G2',axis=1)
studentport = studentport.drop('G3',axis=1)

# %%
#Plot a Correlation Matrix
corr = studentmath.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0
# roundedAvg -0.119134  0.995531    1.000000

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#              Average
# roundedAvg  0.995531
# Medu        0.265905
# studytime   0.261630
# Fedu        0.227918
# famrel      0.070550
# health     -0.082420
# goout      -0.084467
# freetime   -0.113723
# absences   -0.125015
# age        -0.133499
# traveltime -0.151066
# Walc       -0.173906
# Dalc       -0.205792
# failures   -0.405815

# %% [markdown]
# ## Data visualization

# %%
import seaborn as sns
b = sns.factorplot(x="failures", y="goout", hue="sex", data=studentmath, kind="bar", palette="muted" )

# %%
# see how many students had an average math grade > 10 (midpoint, grade values 0-20)
studentmath[(studentmath['Average']>10.00)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 22      GP   M   16       U     LE3       T     4     2   teacher     other
# 23      GP   M   16       U     LE3       T     2     2     other     other
# 26      GP   M   15       U     GT3       T     2     2     other     other
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 28      GP   M   16       U     LE3       A     3     4  services     other
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 30      GP   M   15       U     GT3       T     4     4    health  services
# 31      GP   M   15       U     GT3       T     4     4  services  services
# 32      GP   M   15       R     GT3       T     4     3   teacher   at_home
# 34      GP   M   16       U     GT3       T     3     2     other     other
# 36      GP   M   15       U     LE3       T     4     3   teacher  services
# 37      GP   M   16       R     GT3       A     4     4     other   teacher
# 38      GP   F   15       R     GT3       T     3     4  services    health
# 39      GP   F   15       R     GT3       T     2     2   at_home     other
# 41      GP   M   15       U     LE3       T     4     4   teacher     other
# 42      GP   M   15       U     GT3       T     4     4  services   teacher
# 46      GP   F   16       U     LE3       A     3     3     other  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 338     GP   F   18       U     LE3       T     3     3  services  services
# 340     GP   F   19       U     GT3       T     2     1  services  services
# 342     GP   M   18       U     LE3       T     3     4  services     other
# 344     GP   F   18       U     GT3       T     2     3   at_home     other
# 345     GP   F   18       U     GT3       T     3     2     other  services
# 346     GP   M   18       R     GT3       T     4     3   teacher  services
# 348     GP   F   17       U     GT3       T     4     3    health     other
# 349     MS   M   18       R     GT3       T     3     2     other     other
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 359     MS   F   18       U     LE3       T     1     1   at_home  services
# 360     MS   F   18       R     LE3       A     1     4   at_home     other
# 361     MS   M   18       R     LE3       T     1     1   at_home     other
# 362     MS   F   18       U     GT3       T     3     3  services  services
# 363     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 364     MS   F   17       R     GT3       T     1     2     other  services
# 366     MS   M   18       U     LE3       T     4     4   teacher  services
# 368     MS   F   18       U     GT3       T     2     3   at_home  services
# 369     MS   F   18       R     GT3       T     4     4     other   teacher
# 371     MS   M   18       R     LE3       T     1     2   at_home  services
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 378     MS   F   18       U     GT3       T     3     3     other     other
# 380     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 382     MS   M   17       U     GT3       T     2     3     other  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 393     MS   M   18       R     LE3       T     3     2  services     other
#
#        ...     romantic famrel  freetime  goout  Dalc Walc health absences  \
# 3      ...          yes      3         2      2     1    1      5        2
# 5      ...           no      5         4      2     1    2      5       10
# 6      ...           no      4         4      4     1    1      3        0
# 8      ...           no      4         2      2     1    1      1        0
# 9      ...           no      5         5      1     1    1      5        0
# 11     ...           no      5         2      2     1    1      4        4
# 12     ...           no      4         3      3     1    3      5        2
# 13     ...           no      5         4      3     1    2      3        2
# 14     ...          yes      4         5      2     1    1      3        0
# 15     ...           no      4         4      4     1    2      2        4
# 16     ...           no      3         2      3     1    2      2        6
# 39   13.333333       13.0
# 41   12.000000       12.0
# 42   18.333333       18.0
# 46   11.333333       11.0
# ..         ...        ...
# 338  16.000000       16.0
# 340  11.333333       11.0
# 342  15.333333       15.0
# 344  10.333333       10.0
# 345  13.333333       13.0
# 346  15.666667       16.0
# 348  14.333333       14.0
# 349  12.333333       12.0
# 351  13.000000       13.0
# 354  11.666667       12.0
# 356  12.666667       13.0
# 357  11.666667       12.0
# 359  16.666667       17.0
# 360  13.000000       13.0
# 361  12.333333       12.0
# 362  10.666667       11.0
# 363  15.333333       15.0
# 364  11.666667       12.0
# 366  13.000000       13.0
# 368  10.333333       10.0
# 369  12.333333       12.0
# 371  12.666667       13.0
# 372  11.666667       12.0
# 374  18.666667       19.0
# 376  14.666667       15.0
# 378  15.000000       15.0
# 380  14.333333       14.0
# 382  10.666667       11.0
# 391  15.333333       15.0
# 393  11.000000       11.0
#
# [216 rows x 32 columns]

# %%
studentport[(studentport['Average']>10.00)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 19      GP   M   16       U     LE3       T     4     3    health     other
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 22      GP   M   16       U     LE3       T     4     2   teacher     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 26      GP   M   15       U     GT3       T     2     2     other     other
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 28      GP   M   16       U     LE3       A     3     4  services     other
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 30      GP   M   15       U     GT3       T     4     4    health  services
# 31      GP   M   15       U     GT3       T     4     4  services  services
# 32      GP   M   15       R     GT3       T     4     3   teacher   at_home
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 598     MS   M   18       U     LE3       T     1     2   at_home  services
# 599     MS   M   18       R     GT3       T     4     4   at_home  services
# 600     MS   M   17       R     GT3       T     1     1     other  services
# 602     MS   F   18       U     LE3       T     2     2  services  services
# 606     MS   F   17       U     GT3       T     4     2   teacher     other
# 607     MS   F   17       R     LE3       A     2     1  services     other
# 609     MS   F   18       U     GT3       T     1     2   at_home   at_home
# 611     MS   F   18       R     GT3       T     2     2  services     other
# 612     MS   M   17       R     GT3       T     4     3  services     other
# 614     MS   F   17       R     GT3       T     4     4   teacher  services
# 615     MS   F   17       U     LE3       A     3     2  services     other
# 616     MS   M   18       U     LE3       T     1     1     other  services
# 617     MS   F   18       U     LE3       T     1     1   at_home  services
# 618     MS   F   18       R     LE3       A     1     2   at_home     other
# 619     MS   F   18       U     GT3       T     3     3  services  services
# 620     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 621     MS   F   17       R     GT3       T     1     2     other  services
# 623     MS   M   18       U     LE3       T     4     4   teacher  services
# 628     MS   F   17       U     GT3       T     2     2     other   at_home
# 630     MS   F   18       R     LE3       T     4     4     other     other
# 631     MS   F   18       R     GT3       T     1     1     other     other
# 633     MS   F   18       R     LE3       T     4     4   teacher  services
# 634     MS   F   18       U     GT3       T     3     3     other     other
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 638     MS   M   17       U     GT3       T     2     3     other  services
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#        ...     romantic famrel  freetime  goout  Dalc Walc health absences  \
# 1      ...           no      5         3      3     1    1      3        2
# 2      ...           no      4         3      2     2    3      3        6
# 3      ...          yes      3         2      2     1    1      5        0
# 4      ...           no      4         3      2     1    2      5        0
# 5      ...           no      5         4      2     1    2      5        6
# 6      ...           no      4         4      4     1    1      3        0
# 7      ...           no      4         1      4     1    1      1        2
# 8      ...           no      4         2      2     1    1      1        0
# 9      ...           no      5         5      1     1    1      5        0
# 25   11.000000       11.0
# 26   11.666667       12.0
# 27   11.000000       11.0
# 28   12.333333       12.0
# 29   11.666667       12.0
# 30   10.666667       11.0
# 31   15.000000       15.0
# 32   14.000000       14.0
# ..         ...        ...
# 598  10.666667       11.0
# 599  13.000000       13.0
# 600  13.000000       13.0
# 602  12.000000       12.0
# 606  18.000000       18.0
# 607  11.333333       11.0
# 609  11.333333       11.0
# 611  14.333333       14.0
# 612  10.666667       11.0
# 614  12.000000       12.0
# 615  14.666667       15.0
# 616  13.666667       14.0
# 617  18.000000       18.0
# 618  15.333333       15.0
# 619  12.666667       13.0
# 620  14.666667       15.0
# 621  13.000000       13.0
# 623  15.666667       16.0
# 628  11.000000       11.0
# 630  16.333333       16.0
# 631  11.000000       11.0
# 633  13.666667       14.0
# 634  16.000000       16.0
# 636  18.000000       18.0
# 638  15.000000       15.0
# 641  15.333333       15.0
# 644  10.333333       10.0
# 645  15.333333       15.0
# 646  10.666667       11.0
# 648  10.666667       11.0
#
# [450 rows x 32 columns]

# %% [markdown]
# ###  216 of 395 math grades better than 10 which is approximately 55%
# ### 450 out of 649  Portuguese grades better than 10 which is approximately 69%

# %% [markdown]
# ## I would like to look at the categorical data and will use dummies to convert to numeric values

# %%
# first convert xxxxx non numerics to take a look at which we might like to use as features
#studentmath_with_dummies = pd.get_dummies(data=studentmath, columns = ['sex', 'Mjob', 'Fjob','Medu', 'Fedu','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid','activities', 'nursery','address','reason','guardian'], prefix = ['sex', 'Mjob', 'Fjob','Medu','Fedu','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid', 'activities', 'nursery','address','reason','guardian'] )
studentmath_with_dummies = pd.get_dummies(data=studentmath, columns = ['school', 'sex', 'address', 'famsize', 'Pstatus','Mjob', 'Fjob','reason', 'guardian','schoolsup','famsup', 'paid','activities', 'nursery','higher','internet', 'romantic'], prefix = ['school', 'sex', 'address', 'famsize', 'Pstatus','Mjob', 'Fjob','reason', 'guardian','schoolsup','famsup', 'paid','activities', 'nursery','higher','internet', 'romantic'] )
studentport_with_dummies = pd.get_dummies(data=studentport, columns = ['school', 'sex', 'address', 'famsize', 'Pstatus','Mjob', 'Fjob','reason', 'guardian','schoolsup','famsup', 'paid','activities', 'nursery','higher','internet', 'romantic'], prefix = ['school', 'sex', 'address', 'famsize', 'Pstatus','Mjob', 'Fjob','reason', 'guardian','schoolsup','famsup', 'paid','activities', 'nursery','higher','internet', 'romantic'] )

# one version with Rounded and one with float average
math_d_A = studentmath_with_dummies.drop('roundedAvg', 1)
math_d_R = studentmath_with_dummies.drop('Average', 1)
port_d_A = studentport_with_dummies.drop('roundedAvg', 1)
port_d_R = studentport_with_dummies.drop('Average', 1)

# %%
studentmath_with_dummies.head()
studentmath_with_dummies.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'Average',
#        'roundedAvg', 'school_GP', 'school_MS', 'sex_F', 'sex_M', 'address_R',
#        'address_U', 'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'schoolsup_no', 'schoolsup_yes',
#        'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes', 'activities_no',
#        'activities_yes', 'nursery_no', 'nursery_yes', 'higher_no',
#        'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
#        'romantic_yes'],
#       dtype='object')

# %%
# do a correlation summary and see 
#Plot a Correlation Matrix
corr = math_d_A.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                         age      Medu      Fedu  traveltime  studytime  \
# age                1.000000 -0.163658 -0.163438    0.070641  -0.004140
# Medu              -0.163658  1.000000  0.623455   -0.171639   0.064944
# Fedu              -0.163438  0.623455  1.000000   -0.158194  -0.009175
# traveltime         0.070641 -0.171639 -0.158194    1.000000  -0.100909
# studytime         -0.004140  0.064944 -0.009175   -0.100909   1.000000
# failures           0.243665 -0.236680 -0.250408    0.092239  -0.173563
# famrel             0.053940 -0.003914 -0.001370   -0.016808   0.039731
# freetime           0.016434  0.030891 -0.012846   -0.017025  -0.143198
# goout              0.126964  0.064094  0.043105    0.028540  -0.063904
# Dalc               0.131125  0.019834  0.002386    0.138325  -0.196019
# Walc               0.117276 -0.047123 -0.012631    0.134116  -0.253785
# health            -0.062187 -0.046878  0.014742    0.007501  -0.075616
# absences           0.175230  0.100285  0.024473   -0.012944  -0.062700
# Average           -0.134589  0.224260  0.175852   -0.128197   0.134565
# school_GP         -0.377610  0.133333  0.079807   -0.242308   0.090681
# school_MS          0.377610 -0.133333 -0.079807    0.242308  -0.090681
# sex_F              0.028606 -0.078228 -0.034878   -0.059722   0.306268
# sex_M             -0.028606  0.078228  0.034878    0.059722  -0.306268
# address_R          0.146722 -0.138804 -0.072178    0.328096   0.020912
# address_U         -0.146722  0.138804  0.072178   -0.328096  -0.020912
# famsize_GT3       -0.037847  0.043068  0.058879   -0.063493   0.073595
# famsize_LE3        0.037847 -0.043068 -0.058879    0.063493  -0.073595
# Pstatus_A         -0.029598  0.123565  0.088730   -0.028265  -0.024294
# Pstatus_T          0.029598 -0.123565 -0.088730    0.028265   0.024294
# Mjob_at_home       0.088745 -0.397637 -0.155335    0.148467   0.033122
# Mjob_health       -0.082660  0.251973  0.118501   -0.106708  -0.012977
# Mjob_other         0.032488 -0.235176 -0.197077    0.036544  -0.006288
# Mjob_services     -0.007732  0.051764  0.028032   -0.050943  -0.004476
# Mjob_teacher      -0.058256  0.454911  0.294526   -0.051235  -0.009009
# Fjob_at_home       0.082233 -0.073794 -0.036446   -0.082249   0.031563
# Fjob_health       -0.109842  0.083398  0.163216   -0.088277   0.121107
# romantic_yes          0.027495   0.105664   -0.105664    -0.087122
#
#                    internet_yes  romantic_no  romantic_yes
# age                   -0.112094    -0.164669      0.164669
# Medu                   0.201463    -0.039681      0.039681
# Fedu                   0.127507    -0.015602      0.015602
# traveltime            -0.111302    -0.021962      0.021962
# studytime              0.059422    -0.053285      0.053285
# failures              -0.063451    -0.093137      0.093137
# famrel                 0.032768     0.063816     -0.063816
# freetime               0.051286     0.011182     -0.011182
# goout                  0.074370    -0.007870      0.007870
# Dalc                   0.036210    -0.015121      0.015121
# Walc                   0.011687     0.010141     -0.010141
# health                -0.080189    -0.026342      0.026342
# absences               0.101701    -0.153384      0.153384
# Average                0.102628     0.102731     -0.102731
# school_GP              0.133578     0.060700     -0.060700
# school_MS             -0.133578    -0.060700      0.060700
# sex_F                 -0.044113    -0.102023      0.102023
# sex_M                  0.044113     0.102023     -0.102023
# address_R             -0.216842     0.005257     -0.005257
# address_U              0.216842    -0.005257      0.005257
# famsize_GT3           -0.000720     0.034395     -0.034395
# famsize_LE3            0.000720    -0.034395      0.034395
# Pstatus_A             -0.070074    -0.040451      0.040451
# Pstatus_T              0.070074     0.040451     -0.040451
# Mjob_at_home          -0.231160    -0.019326      0.019326
# Mjob_health            0.089064    -0.031343      0.031343
# Mjob_other            -0.048733    -0.043476      0.043476
# Mjob_services          0.080531     0.041810     -0.041810
# Mjob_teacher           0.128292     0.051288     -0.051288
# Fjob_at_home           0.010579    -0.056706      0.056706
# Fjob_health           -0.032293     0.000391     -0.000391
# Fjob_other            -0.064674     0.059505     -0.059505
# Fjob_services          0.098841    -0.022762      0.022762
# Fjob_teacher          -0.030037    -0.026933      0.026933
# reason_course         -0.067187     0.049613     -0.049613
# reason_home            0.048775    -0.030914      0.030914
# reason_other          -0.023221    -0.074026      0.074026
# reason_reputation      0.039084     0.025374     -0.025374
# guardian_father        0.049152     0.039359     -0.039359
# guardian_mother       -0.020340     0.037525     -0.037525
# guardian_other        -0.041116    -0.124045      0.124045
# schoolsup_no           0.009683    -0.080716      0.080716
# schoolsup_yes         -0.009683     0.080716     -0.080716
# famsup_no             -0.103581     0.012440     -0.012440
# famsup_yes             0.103581    -0.012440      0.012440
# paid_no               -0.153132     0.005536     -0.005536
# paid_yes               0.153132    -0.005536      0.005536
# activities_no         -0.048663     0.019651     -0.019651
# activities_yes         0.048663    -0.019651      0.019651
# nursery_no            -0.007830     0.027495     -0.027495
# nursery_yes            0.007830    -0.027495      0.027495
# higher_no             -0.020374    -0.105664      0.105664
# higher_yes             0.020374     0.105664     -0.105664
# internet_no           -1.000000     0.087122     -0.087122
# internet_yes           1.000000    -0.087122      0.087122
# romantic_no           -0.087122     1.000000     -1.000000
# romantic_yes           0.087122    -1.000000      1.000000
#
# [57 rows x 57 columns]

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#                     Average
# Medu               0.224260
# higher_yes         0.189483
# Fedu               0.175852
# schoolsup_no       0.137644
# studytime          0.134565
# Mjob_health        0.129334
# Fjob_teacher       0.122597
# address_U          0.107297
# romantic_no        0.102731
# internet_yes       0.102628
# sex_M              0.101122
# reason_reputation  0.098826
# paid_yes           0.089511
# Mjob_services      0.084902
# famsize_LE3        0.082560
# Mjob_teacher       0.066383
# nursery_yes        0.065145
# famsup_no          0.061553
# Fjob_health        0.047473
# guardian_father    0.045001
# school_GP          0.043285
# Pstatus_A          0.043048
# activities_yes     0.040859
# reason_other       0.033857
# famrel             0.021653
# Fjob_at_home       0.008591
# freetime           0.003773
# guardian_mother    0.000808
# Fjob_services     -0.001635
# absences          -0.005909
# reason_home       -0.012343
# activities_no     -0.040859
# Pstatus_T         -0.043048
# school_MS         -0.043285
# famsup_yes        -0.061553
# nursery_no        -0.065145
# guardian_other    -0.070545
# Dalc              -0.072508
# health            -0.080380
# famsize_GT3       -0.082560
# Fjob_other        -0.086473
# Walc              -0.088025
# paid_no           -0.089511
# reason_course     -0.099345
# sex_F             -0.101122
# internet_no       -0.102628
# romantic_yes      -0.102731
# Mjob_at_home      -0.104032
# address_R         -0.107297
# Mjob_other        -0.125160
# traveltime        -0.128197
# age               -0.134589
# schoolsup_yes     -0.137644
# goout             -0.154511
# higher_no         -0.189483
# failures          -0.375759

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#                     Average
# Medu               0.224260
# higher_yes         0.189483
# Fedu               0.175852
# schoolsup_no       0.137644
# studytime          0.134565
# Mjob_health        0.129334
# Fjob_teacher       0.122597
# address_U          0.107297
# romantic_no        0.102731
# internet_yes       0.102628
# sex_M              0.101122
# reason_reputation  0.098826
# paid_yes           0.089511
# Mjob_services      0.084902
# famsize_LE3        0.082560
# Mjob_teacher       0.066383
# nursery_yes        0.065145
# famsup_no          0.061553
# Fjob_health        0.047473
# guardian_father    0.045001
# school_GP          0.043285
# Pstatus_A          0.043048
# activities_yes     0.040859
# reason_other       0.033857
# famrel             0.021653
# Fjob_at_home       0.008591
# freetime           0.003773
# guardian_mother    0.000808
# Fjob_services     -0.001635
# absences          -0.005909
# reason_home       -0.012343
# activities_no     -0.040859
# Pstatus_T         -0.043048
# school_MS         -0.043285
# famsup_yes        -0.061553
# nursery_no        -0.065145
# guardian_other    -0.070545
# Dalc              -0.072508
# health            -0.080380
# famsize_GT3       -0.082560
# Fjob_other        -0.086473
# Walc              -0.088025
# paid_no           -0.089511
# reason_course     -0.099345
# sex_F             -0.101122
# internet_no       -0.102628
# romantic_yes      -0.102731
# Mjob_at_home      -0.104032
# address_R         -0.107297
# Mjob_other        -0.125160
# traveltime        -0.128197
# age               -0.134589
# schoolsup_yes     -0.137644
# goout             -0.154511
# higher_no         -0.189483
# failures          -0.375759

# %% [markdown]
# ## Little more exploring with some grapsh

# %%
math_d_A[['Average']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fc3b908>]], dtype=object)

# %%
port_d_A[['Average']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x123a79a90>]], dtype=object)

# %%
# Math , failures / average
plt.figure(figsize = (10,6))
sns.barplot(x='failures', y = 'Average', data = math_d_A)

# %%
# Porguguese , failures / average
plt.figure(figsize = (10,6))
sns.barplot(x='failures', y = 'Average', data = port_d_A)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='higher_yes', y = 'Average', data = math_d_A)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='higher_yes', y = 'Average', data = port_d_A)

# %% [markdown]
# ##  Model Math Data
# ### Now time to run a LASSO regression Model on the data sets

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from numpy import loadtxt, where
from pylab import scatter, show, legend, xlabel, ylabel
from sklearn import metrics

# %%
# feature columns will be set to all the data
feature_cols = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
       'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences',
       'school_GP', 'school_MS', 'sex_F', 'sex_M', 'address_R', 'address_U',
       'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Mjob_at_home',
       'Mjob_health', 'Mjob_other', 'Mjob_services', 'Mjob_teacher',
       'Fjob_at_home', 'Fjob_health', 'Fjob_other', 'Fjob_services',
       'Fjob_teacher', 'reason_course', 'reason_home', 'reason_other',
       'reason_reputation', 'guardian_father', 'guardian_mother',
       'guardian_other', 'schoolsup_no', 'schoolsup_yes', 'famsup_no',
       'famsup_yes', 'paid_no', 'paid_yes', 'activities_no', 'activities_yes',
       'nursery_no', 'nursery_yes', 'higher_no', 'higher_yes', 'internet_no',
       'internet_yes', 'romantic_no', 'romantic_yes']

# %% [markdown]
# ## Look at the Math dataset

# %%
#  Setup X and y
X = math_d_A[feature_cols]
y = math_d_A.Average

# %%
#  split the data into training and testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.coef_
# Out:
# array([ -3.05284079e-01,   5.36664321e-01,  -6.72472692e-02,
#         -6.79124440e-01,   6.46851774e-01,  -1.47795180e+00,
#          6.44213402e-03,   2.63522620e-01,  -2.58120112e-01,
#         -8.25677294e-02,   3.22273146e-02,  -6.22081477e-02,
#          2.65913112e-02,   3.59204407e+11,   3.59204407e+11,
#          5.71427737e+11,   5.71427737e+11,  -2.72253971e+09,
#         -2.72253971e+09,  -1.39707310e+11,  -1.39707310e+11,
#          1.19265470e+11,   1.19265470e+11,  -5.03357365e+11,
#         -5.03357365e+11,  -5.03357365e+11,  -5.03357365e+11,
#         -5.03357365e+11,  -1.63601827e+11,  -1.63601827e+11,
#         -1.63601827e+11,  -1.63601827e+11,  -1.63601827e+11,
#         -3.05468774e+10,  -3.05468774e+10,  -3.05468774e+10,
#         -3.05468774e+10,   1.05890557e+12,   1.05890557e+12,
#          1.05890557e+12,  -2.52275373e+10,  -2.52275374e+10,
#         -9.70454848e+11,  -9.70454848e+11,  -4.78936010e+10,
#         -4.78936010e+10,   7.93996368e+10,   7.93996368e+10,
#          3.55263269e+09,   3.55263269e+09,  -6.81944649e+10,
#         -6.81944649e+10,  -5.20836241e+11,  -5.20836241e+11,
#         -9.90995607e+10,  -9.90995607e+10])

# %%
import numpy as np
from sklearn import metrics
preds = lm.predict(X_test)
print('RMSE (no regularization) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (no regularization) = 3.58427604693

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.coef_
# Out:
# array([ -3.05284079e-01,   5.36664321e-01,  -6.72472692e-02,
#         -6.79124440e-01,   6.46851774e-01,  -1.47795180e+00,
#          6.44213402e-03,   2.63522620e-01,  -2.58120112e-01,
#         -8.25677294e-02,   3.22273146e-02,  -6.22081477e-02,
#          2.65913112e-02,   3.59204407e+11,   3.59204407e+11,
#          5.71427737e+11,   5.71427737e+11,  -2.72253971e+09,
#         -2.72253971e+09,  -1.39707310e+11,  -1.39707310e+11,
#          1.19265470e+11,   1.19265470e+11,  -5.03357365e+11,
#         -5.03357365e+11,  -5.03357365e+11,  -5.03357365e+11,
#         -5.03357365e+11,  -1.63601827e+11,  -1.63601827e+11,
#         -1.63601827e+11,  -1.63601827e+11,  -1.63601827e+11,
#         -3.05468774e+10,  -3.05468774e+10,  -3.05468774e+10,
#         -3.05468774e+10,   1.05890557e+12,   1.05890557e+12,
#          1.05890557e+12,  -2.52275373e+10,  -2.52275374e+10,
#         -9.70454848e+11,  -9.70454848e+11,  -4.78936010e+10,
#         -4.78936010e+10,   7.93996368e+10,   7.93996368e+10,
#          3.55263269e+09,   3.55263269e+09,  -6.81944649e+10,
#         -6.81944649e+10,  -5.20836241e+11,  -5.20836241e+11,
#         -9.90995607e+10,  -9.90995607e+10])

# %%
preds = lm.predict(X_test)
print('RMSE (no regularization) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (no regularization) = 3.58427604693

# %%
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (296, 56) (296,)
# (99, 56) (99,)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
# some of the predictions
predictions[0:5]
# Out:
# array([  8.8270874 ,  12.98846436,   3.17370605,  10.48687744,   8.11462402])

# %% [markdown]
# ## LASSO Linear regression model on MATH data

# %%
# lasso (alpha must be positive, larger means more regularization)
from sklearn.linear_model import Lasso
las = Lasso(alpha=0.1, normalize=True)
las.fit(X_train, y_train)
las.coef_
preds = las.predict(X_test)
print('RMSE (Lasso reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso reg.) = 3.29524999103

# %%
# Build Lasso Model
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_boston
  
# xxxxxx   scaler = StandardScaler()
#X = scaler.fit_transform(math_d["data"])
#Y = boston["target"]
names = feature_cols

alpha_range = 10.**np.arange(-5, 5)
print('Alpha Range: ', alpha_range, '\n')

lasso_model = LassoCV(normalize=True, alphas=alpha_range)
lasso_model.fit(X_train, y_train)

#  A helper method for pretty-printing linear models
def pretty_print_linear(coefs, names = None, sort = False):
    if names == None:
        names = ["X%s" % x for x in range(len(coefs))]
    lst = zip(coefs, names)
    if sort:
        lst = sorted(lst,  key = lambda x:-np.abs(x[0]))
    return " + ".join("%s * %s" % (round(coef, 3), name)
                                   for coef, name in lst)
  
print("Lasso model: ", pretty_print_linear(lasso_model.coef_, names, sort = True))
print('Optimal Alpha Value: ',lasso_model.alpha_)
# Out:
# Alpha Range:  [  1.00000000e-05   1.00000000e-04   1.00000000e-03   1.00000000e-02
#    1.00000000e-01   1.00000000e+00   1.00000000e+01   1.00000000e+02
#    1.00000000e+03   1.00000000e+04]
#
# Lasso model:  -1.542 * higher_no + -1.43 * failures + 1.353 * schoolsup_no + 0.965 * Mjob_health + 0.753 * Mjob_services + 0.611 * Fjob_teacher + 0.603 * romantic_no + -0.57 * famsize_GT3 + -0.558 * sex_F + 0.468 * famsup_no + -0.431 * traveltime + -0.414 * reason_course + 0.385 * studytime + 0.263 * Medu + -0.188 * Mjob_other + -0.099 * age + -0.087 * goout + 0.066 * reason_reputation + 0.054 * guardian_father + 0.0 * sex_M + 0.0 * higher_yes + -0.0 * romantic_yes + 0.0 * Fedu + 0.0 * famrel + 0.0 * freetime + -0.0 * Dalc + -0.0 * Walc + -0.0 * health + 0.0 * absences + 0.0 * school_GP + -0.0 * school_MS + -0.0 * address_R + 0.0 * address_U + 0.0 * famsize_LE3 + 0.0 * Pstatus_A + -0.0 * Pstatus_T + 0.0 * Mjob_at_home + -0.0 * Mjob_teacher + 0.0 * Fjob_at_home + -0.0 * Fjob_health + -0.0 * Fjob_other + 0.0 * Fjob_services + 0.0 * reason_home + -0.0 * reason_other + -0.0 * guardian_mother + 0.0 * guardian_other + -0.0 * schoolsup_yes + -0.0 * famsup_yes + -0.0 * paid_no + 0.0 * paid_yes + -0.0 * activities_no + 0.0 * activities_yes + -0.0 * nursery_no + 0.0 * nursery_yes + -0.0 * internet_no + 0.0 * internet_yes
# Optimal Alpha Value:  0.01

# %%
lasso_model.coef_
preds = lasso_model.predict(X_test)
print('RMSE (Lasso CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso CV reg.) = 3.23008131319

# %% [markdown]
# # Run lasso Regression on Portuguese data set

# %%
X = port_d_A[feature_cols]
y = port_d_A.Average

# %%
#  split the data into training and testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.coef_
# Out:
# array([  8.46846195e-02,   3.58823641e-03,   1.97615074e-01,
#          1.17777747e-01,   3.60230720e-01,  -1.11918615e+00,
#          2.21785144e-01,  -1.07538152e-01,  -4.22894248e-02,
#         -1.05525151e-01,  -1.23649979e-01,  -1.05636362e-01,
#         -4.52157608e-02,   7.25929660e+09,   7.25929660e+09,
#          3.00223240e+11,   3.00223240e+11,   5.68146976e+10,
#          5.68146976e+10,   1.27556601e+09,   1.27556601e+09,
#         -2.29089457e+10,  -2.29089457e+10,   1.46309231e+11,
#          1.46309231e+11,   1.46309231e+11,   1.46309231e+11,
#          1.46309231e+11,  -2.05465803e+11,  -2.05465803e+11,
#         -2.05465803e+11,  -2.05465803e+11,  -2.05465803e+11,
#         -9.78096992e+10,  -9.78096992e+10,  -9.78096992e+10,
#         -9.78096992e+10,  -2.64558792e+11,  -2.64558792e+11,
#         -2.64558792e+11,   1.01528956e+11,   1.01528956e+11,
#          9.87604834e+10,   9.87604834e+10,  -1.85740714e+10,
#         -1.85740714e+10,   4.30742797e+11,   4.30742797e+11,
#         -8.86148044e+00,  -8.84379605e+00,  -2.80477744e+11,
#         -2.80477744e+11,   5.31758965e+10,   5.31758965e+10,
#         -3.18888219e+11,  -3.18888219e+11])

# %%
las = Lasso(alpha=0.1, normalize=True)
las.fit(X_train, y_train)
las.coef_
preds = las.predict(X_test)
print('RMSE (Lasso reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso reg.) = 3.05359116089

# %%
names = feature_cols

alpha_range = 10.**np.arange(-5, 5)
print('Alpha Range: ', alpha_range, '\n')

lasso_model = LassoCV(normalize=True, alphas=alpha_range)
lasso_model.fit(X_train, y_train)

#  A helper method for pretty-printing linear models
def pretty_print_linear(coefs, names = None, sort = False):
    if names == None:
        names = ["X%s" % x for x in range(len(coefs))]
    lst = zip(coefs, names)
    if sort:
        lst = sorted(lst,  key = lambda x:-np.abs(x[0]))
    return " + ".join("%s * %s" % (round(coef, 3), name)
                                   for coef, name in lst)
  
print("Lasso model: ", pretty_print_linear(lasso_model.coef_, names, sort = True))
print('Optimal Alpha Value: ',lasso_model.alpha_)
# Out:
# Alpha Range:  [  1.00000000e-05   1.00000000e-04   1.00000000e-03   1.00000000e-02
#    1.00000000e-01   1.00000000e+00   1.00000000e+01   1.00000000e+02
#    1.00000000e+03   1.00000000e+04]
#
# Lasso model:  -1.393 * higher_no + -1.125 * failures + 0.872 * school_GP + 0.358 * reason_reputation + 0.337 * schoolsup_no + 0.218 * studytime + -0.092 * Walc + -0.079 * Dalc + 0.069 * Medu + 0.045 * Fedu + -0.007 * internet_no + 0.0 * higher_yes + -0.0 * school_MS + -0.0 * schoolsup_yes + 0.0 * internet_yes + 0.0 * age + -0.0 * traveltime + 0.0 * famrel + -0.0 * freetime + -0.0 * goout + -0.0 * health + -0.0 * absences + 0.0 * sex_F + -0.0 * sex_M + -0.0 * address_R + 0.0 * address_U + -0.0 * famsize_GT3 + 0.0 * famsize_LE3 + -0.0 * Pstatus_A + 0.0 * Pstatus_T + -0.0 * Mjob_at_home + 0.0 * Mjob_health + -0.0 * Mjob_other + -0.0 * Mjob_services + 0.0 * Mjob_teacher + -0.0 * Fjob_at_home + 0.0 * Fjob_health + 0.0 * Fjob_other + -0.0 * Fjob_services + 0.0 * Fjob_teacher + -0.0 * reason_course + 0.0 * reason_home + -0.0 * reason_other + -0.0 * guardian_father + 0.0 * guardian_mother + -0.0 * guardian_other + -0.0 * famsup_no + 0.0 * famsup_yes + 0.0 * paid_no + -0.0 * paid_yes + -0.0 * activities_no + 0.0 * activities_yes + -0.0 * nursery_no + 0.0 * nursery_yes + 0.0 * romantic_no + -0.0 * romantic_yes
# Optimal Alpha Value:  0.01

# %%
lasso_model.coef_
preds = lasso_model.predict(X_test)
print('RMSE (Lasso CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso CV reg.) = 2.69153022472
