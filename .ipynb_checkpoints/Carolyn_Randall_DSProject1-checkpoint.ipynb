# %% [markdown]
# #  Carolyn Randall - Data Science project
# ### Student Grades Datasets

# %% [markdown]
# ## Summary

# %%
#  import libraries
import pandas as pd
import numpy as np
from sklearn.dummy import DummyClassifier
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import pandas_profiling

# this allows plots to appear directly in the notebook
# %matplotlib inline
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# Read the data sets into Dataframes
# Data source are csv files downloaded from Kaggle.  
# Let's read the student maths data set into a Dataframe called 'studentmath
studentmath = pd.read_csv('student-mat.csv')  
# read the student portuguese data into a Dataframe called 'studentport'
studentport = pd.read_csv('student-por.csv')

# %% [markdown]
# ## Explore the data

# %% [markdown]
# ### Definitions of the data and what the values mean
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# 2.	sex - student's sex (binary: 'F' - female or 'M' - male)
#
# 3.	age - student's age (numeric: from 15 to 22)
#
# 4.	address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# 5.	famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# 6.	Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# 7.	Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade) 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8.	Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9.	Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10.	Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services'(e.g. administrative or police), 'at_home' or 'other')
# 11.	reason - reason to choose this school (nominal: close to 'home', school 'reputation','course' preference or 'other')
# 12.	guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13.	traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min. 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14.	studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15.	failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16.	schoolsup - extra educational support (binary: yes or no)
# 17.	famsup - family educational support (binary: yes or no)
# 18.	paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19.	activities - extra-curricular activities (binary: yes or no)
# 20.	nursery - attended nursery school (binary: yes or no)
# 21.	higher - wants to take higher education (binary: yes or no)
# 22.	internet - Internet access at home (binary: yes or no)
# 23.	romantic - with a romantic relationship (binary: yes or no)
# 24.	famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25.	freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26.	goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27.	Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28.	Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29.	health - current health status (numeric: from 1 - very bad to 5 - very good)	30.	absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
# 	1.	G1 - first period grade (numeric: from 0 to 20)
# 	2.	G2 - second period grade (numeric: from 0 to 20)
# 	3.	G3 - final grade (numeric: from 0 to 20, output target)

# %%
# take a quick look at the data using head function
studentmath.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
studentport.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# let's see how many rows and columns we have
studentmath.shape
# Out:
# (395, 33)

# %%
studentport.shape
# Out:
# (649, 33)

# %%
# Use describe to take another look at some statistics
# This only summarizes the numeric data
studentmath.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# Use describe to take another look at some statistics
# This only summarizes the numeric data
studentport.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
# how do you see stats on types of of the dataxxx

# %%
pandas_profiling.ProfileReport(studentmath)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
pandas_profiling.ProfileReport(studentport)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
# found these functions on kaggle so using them they look useful to see data types and values
def get_feature_lists_by_dtype(data):
    features = data.columns.tolist()
    output = {}
    for f in features:
        dtype = str(data[f].dtype)
        if dtype not in output.keys(): output[dtype] = [f]
        else: output[dtype] += [f]
    return output

def show_uniques(data,features):
    for f in features:
        if len(data[f].unique()) < 30:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()))
        else:
            print("%s: count(%s) %s" % (f,len(data[f].unique()),data[f].unique()[0:10]))
def show_all_uniques(data):
    dtypes = get_feature_lists_by_dtype(data)
    for key in dtypes.keys():
        print(key + "\n")
        show_uniques(data,dtypes[key])
        print()

# %%
show_all_uniques(studentmath)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 2 1]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# ...

# %%
show_all_uniques(studentport)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 1 2]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# ...

# %%
# lets make sure we have the same features in both data sets
studentport.columns == studentmath.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True], dtype=bool)

# %%
# let's check if the datasets have any missing data
studentmath.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# let's check if the datasets have any missing data
studentport.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# G1 and G2 are highly correlated to G3 (as G3 is the final grade)
#  I am going to use the average of the three grades in my modeling
# G1, G2 and G3 are integers so convert Average to an integer also
studentmath['Average'] = ((studentmath.G1 + studentmath.G2 + studentmath.G3)/3)
studentmath['roundedAvg'] = round(studentmath.Average, 0)

# %%
#now drop the original three and keep the average
studentmath = studentmath.drop('G1',axis=1)
studentmath = studentmath.drop('G2',axis=1)
studentmath = studentmath.drop('G3',axis=1)

# %%
#studentmath['roundedAvg'] = round(studentmath.Average, 0)
show_all_uniques(studentmath)
# Out:
# object
#
# school: count(2) ['GP' 'MS']
# sex: count(2) ['F' 'M']
# address: count(2) ['U' 'R']
# famsize: count(2) ['GT3' 'LE3']
# Pstatus: count(2) ['A' 'T']
# Mjob: count(5) ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: count(5) ['teacher' 'other' 'services' 'health' 'at_home']
# reason: count(4) ['course' 'other' 'home' 'reputation']
# guardian: count(3) ['mother' 'father' 'other']
# schoolsup: count(2) ['yes' 'no']
# famsup: count(2) ['no' 'yes']
# paid: count(2) ['no' 'yes']
# activities: count(2) ['no' 'yes']
# nursery: count(2) ['yes' 'no']
# higher: count(2) ['yes' 'no']
# internet: count(2) ['no' 'yes']
# romantic: count(2) ['no' 'yes']
#
# int64
#
# age: count(8) [18 17 15 16 19 22 20 21]
# Medu: count(5) [4 1 3 2 0]
# Fedu: count(5) [4 1 2 3 0]
# traveltime: count(4) [2 1 3 4]
# studytime: count(4) [2 3 1 4]
# failures: count(4) [0 3 2 1]
# famrel: count(5) [4 5 3 1 2]
# freetime: count(5) [3 2 4 1 5]
# goout: count(5) [4 3 2 1 5]
# Dalc: count(5) [1 2 5 3 4]
# ...

# %%
# G1 and G2 are highly correlated to G3 (as G3 is the final grade)
#  I am going to use the average of the three grades in my modeling
studentport['Average'] = ((studentport.G1 + studentport.G2 + studentport.G3)/3)
studentport['roundedAvg'] = round(studentport.Average, 0)

# %%
#now drop the original three and keep the average
studentport = studentport.drop('G1',axis=1)
studentport = studentport.drop('G2',axis=1)
studentport = studentport.drop('G3',axis=1)

# %%
# do a correlation summary and see 
#Plot a Correlation Matrix
corr = studentmath.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#              Average
# roundedAvg  0.997283
# Medu        0.224260
# Fedu        0.175852
# studytime   0.134565
# famrel      0.021653
# freetime    0.003773
# absences   -0.005909
# Dalc       -0.072508
# health     -0.080380
# Walc       -0.088025
# traveltime -0.128197
# age        -0.134589
# goout      -0.154511
# failures   -0.375759

# %%
### Looking at the correlations of just the numeric data we can identify some features we may like
### to try in our modelling  
####  Medu, studytime, Fedu, traveltime, age and failures

# %%
# do a correlation summary and see 
#Plot a Correlation Matrix
corr = studentport.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#              Average
# roundedAvg  0.995531
# Medu        0.265905
# studytime   0.261630
# Fedu        0.227918
# famrel      0.070550
# health     -0.082420
# goout      -0.084467
# freetime   -0.113723
# absences   -0.125015
# age        -0.133499
# traveltime -0.151066
# Walc       -0.173906
# Dalc       -0.205792
# failures   -0.405815

# %%
### Looking at the correlations of just the numeric data we can identify some features we may like
### to try in our modelling  
####  Medu, studytime, Fedu, failures and Daily Alcohol

# %% [markdown]
# ## Data visualization

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='Medu', y = 'Average', hue = 'Fedu', data = studentmath)

# %%
# it looks like value 0 was used for unknown education as it does follow as the rest that

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='traveltime', y = 'Average', hue = 'failures', data = studentmath)

# %%
import seaborn as sns
b = sns.factorplot(x="school", y="age", hue="sex", data=studentmath, kind="bar", palette="muted" )

# %%
# see how many students had an average math grade > 10 (midpoint, grade values 0-20)
studentmath[(studentmath['Average']>10.00)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# ...

# %%
studentport[(studentport['Average']>10.00)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# ...

# %% [markdown]
# ###  216 of 395 math grades better than 10 which is approximately 55%
# ### 450 out of 649  Portuguese grades better than 10 which is approximately 69%

# %% [markdown]
# #### take some of the variables that look to convert using dummy variables  maybe do visualizing first?

# %%
# can see grade distribution using the integer value of average - so a histogr

# %%
# Now let's group the data by the species
byMedu = studentmath.groupby('Medu')
byMedu.describe()
# Out:
#                Average        Dalc        Fedu        Walc    absences  \
# Medu
# 0    count    3.000000    3.000000    3.000000    3.000000    3.000000
#      mean    12.555556    1.666667    1.666667    2.666667    0.666667
#      std      3.976784    0.577350    0.577350    1.527525    1.154701
#      min      8.000000    1.000000    1.000000    1.000000    0.000000
#      25%     11.166667    1.500000    1.500000    2.000000    0.000000
#      50%     14.333333    2.000000    2.000000    3.000000    0.000000
#      75%     14.833333    2.000000    2.000000    3.500000    1.000000
#      max     15.333333    2.000000    2.000000    4.000000    2.000000
# 1    count   59.000000   59.000000   59.000000   59.000000   59.000000
#      mean     9.197740    1.525424    1.457627    2.525424    3.932203
#      std      3.301642    0.878006    0.750219    1.304580    4.802530
#      min      2.333333    1.000000    0.000000    1.000000    0.000000
# ...

# %%
byMedu = studentport.groupby('Medu')
byMedu.describe()
# Out:
#                Average        Dalc        Fedu        Walc    absences  \
# Medu
# 0    count    6.000000    6.000000    6.000000    6.000000    6.000000
#      mean    11.222222    1.666667    1.333333    2.666667    0.833333
#      std      1.746955    0.816497    0.816497    1.632993    2.041241
#      min      9.333333    1.000000    0.000000    1.000000    0.000000
#      25%     10.166667    1.000000    1.000000    1.250000    0.000000
#      50%     11.000000    1.500000    1.500000    2.500000    0.000000
#      75%     11.583333    2.000000    2.000000    3.750000    0.000000
#      max     14.333333    3.000000    2.000000    5.000000    5.000000
# 1    count  143.000000  143.000000  143.000000  143.000000  143.000000
#      mean    10.573427    1.587413    1.370629    2.419580    3.377622
#      std      2.691320    1.023173    0.708881    1.318410    4.148314
#      min      1.666667    1.000000    0.000000    1.000000    0.000000
# ...

# %%
# it is not consistent, the eduation level of 0

# %%
studentmath[['Average']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116e360b8>]], dtype=object)

# %%
studentport[['Average']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113f60dd8>]], dtype=object)

# %%
sns.lmplot(x='Medu', y="Fedu", hue="roundedAvg", data=studentmath, fit_reg=True)

# %%
sns.lmplot(x='Medu', y="Fedu", hue="roundedAvg", data=studentport, fit_reg=True)

# %% [markdown]
# ## I would like to look at the categorical data and will use dummies to convert to numeric values

# %%
# first convert xxxxx non numerics to take a look at which we might like to use as features
#studentmath_with_dummies = pd.get_dummies(data=studentmath, columns = ['sex', 'Mjob', 'Fjob','Medu', 'Fedu','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid','activities', 'nursery','address','reason','guardian'], prefix = ['sex', 'Mjob', 'Fjob','Medu','Fedu','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid', 'activities', 'nursery','address','reason','guardian'] )
studentmath_with_dummies = pd.get_dummies(data=studentmath, columns = ['sex', 'Mjob', 'Fjob','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid','activities', 'nursery','address','reason','guardian'], prefix = ['sex', 'Mjob', 'Fjob','school','internet', 'higher', 'Pstatus', 'romantic','famsize','paid', 'activities', 'nursery','address','reason','guardian'] )

# %%
studentmath_with_dummies.head()
studentmath_with_dummies.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'Average', 'roundedAvg', 'sex_F', 'sex_M',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'school_GP', 'school_MS',
#        'internet_no', 'internet_yes', 'higher_no', 'higher_yes', 'Pstatus_A',
#        'Pstatus_T', 'romantic_no', 'romantic_yes', 'famsize_GT3',
#        'famsize_LE3', 'paid_no', 'paid_yes', 'activities_no', 'activities_yes',
#        'nursery_no', 'nursery_yes', 'address_R', 'address_U', 'reason_course',
#        'reason_home', 'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other'],
#       dtype='object')

# %%
# drop the rem

# %%
# do a correlation summary and see 
#Plot a Correlation Matrix
corr = studentmath_with_dummies.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                         age      Medu      Fedu  traveltime  studytime  \
# age                1.000000 -0.163658 -0.163438    0.070641  -0.004140
# Medu              -0.163658  1.000000  0.623455   -0.171639   0.064944
# Fedu              -0.163438  0.623455  1.000000   -0.158194  -0.009175
# traveltime         0.070641 -0.171639 -0.158194    1.000000  -0.100909
# studytime         -0.004140  0.064944 -0.009175   -0.100909   1.000000
# failures           0.243665 -0.236680 -0.250408    0.092239  -0.173563
# famrel             0.053940 -0.003914 -0.001370   -0.016808   0.039731
# freetime           0.016434  0.030891 -0.012846   -0.017025  -0.143198
# goout              0.126964  0.064094  0.043105    0.028540  -0.063904
# Dalc               0.131125  0.019834  0.002386    0.138325  -0.196019
# Walc               0.117276 -0.047123 -0.012631    0.134116  -0.253785
# health            -0.062187 -0.046878  0.014742    0.007501  -0.075616
# ...

# %%
#Extract ''Average'' column, because 'Average' is our target value
corr_left = pd.DataFrame(corr['Average'].drop('Average'))
corr_left.sort_values(by = 'Average', ascending = False)
# Out:
#                     Average
# roundedAvg         0.997283
# Medu               0.224260
# higher_yes         0.189483
# Fedu               0.175852
# studytime          0.134565
# Mjob_health        0.129334
# Fjob_teacher       0.122597
# address_U          0.107297
# romantic_no        0.102731
# internet_yes       0.102628
# sex_M              0.101122
# reason_reputation  0.098826
# paid_yes           0.089511
# Mjob_services      0.084902
# famsize_LE3        0.082560
# Mjob_teacher       0.066383
# nursery_yes        0.065145
# Fjob_health        0.047473
# guardian_father    0.045001
# school_GP          0.043285
# Pstatus_A          0.043048
# activities_yes     0.040859
# reason_other       0.033857
# famrel             0.021653
# Fjob_at_home       0.008591
# freetime           0.003773
# guardian_mother    0.000808
# Fjob_services     -0.001635
# absences          -0.005909
# reason_home       -0.012343
# activities_no     -0.040859
# Pstatus_T         -0.043048
# ...

# %%
# looks like for math average grade the significant correlations are Medu, failures, Fedu, higher_yes, goout

# %% [markdown]
# ### Try some models

# %%
# now try linear regression 
# check the distribution of Price vs. EstimatedPrice using a scatterplot
import seaborn as sns
sns.set_style("darkgrid")

sns.lmplot(y='Average', x='Medu', data=studentmath_with_dummies)

# %%
sns.lmplot(y='Average', x='failures', data=studentmath_with_dummies)

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from numpy import loadtxt, where
from pylab import scatter, show, legend, xlabel, ylabel
from sklearn import metrics
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# TASK 2: define features
#feature_cols = ['higher_yes', 'failures']
feature_cols = ['Medu', 'Fedu', 'goout', 'failures']
X = studentmath_with_dummies[feature_cols]
y = studentmath_with_dummies.Average
#y = studentmath_with_dummies.roundedAvg

# %%
# TASK 3: split the data into training and testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#  try some more to get a better score

# %% [markdown]
# That's why the models I suggested were numeric regression models; linear regression, Lasso, Ridge, Elastic Net, Decision trees & Random Forests (although some can be used for both regression and classification)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.coef_
# Out:
# array([ 0.67962843, -0.10658017, -0.30314956, -1.79734408])

# %%
import numpy as np
from sklearn import metrics
preds = lm.predict(X_test)
print('RMSE (no regularization) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (no regularization) = 3.08625864516

# %%
# ridge regression (alpha must be positive, larger means more regularization)
from sklearn.linear_model import Ridge
rreg = Ridge(alpha=0.1, normalize=True)
rreg.fit(X_train, y_train)
rreg.coef_
preds = rreg.predict(X_test)
print('RMSE (Ridge reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Ridge reg.) = 3.05787802806

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB()
NB_model.fit(X_train, y_train)
y_pred_class = NB_model.predict(X_test)
# Print the new accuracy rate
print(metrics.accuracy_score(y_test, y_pred_class))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-eebe9ba84ad6> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 NB_model = GaussianNB()
# ----> 3 NB_model.fit(X_train, y_train)
#       4 y_pred_class = NB_model.predict(X_test)
#       5 # Print the new accuracy rate
#
# /Applications/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     182         X, y = check_X_y(X, y)
#     183         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 184                                  sample_weight=sample_weight)
#     185
#     186     @staticmethod
#
# /Applications/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     344             self.classes_ = None
#     345
# ...

# %%
# use RidgeCV to select best alpha
from sklearn.linear_model import RidgeCV
alpha_range = 10.**np.arange(-2, 3)
rregcv = RidgeCV(normalize=True, scoring='neg_mean_squared_error', alphas=alpha_range)
rregcv.fit(X_train, y_train)

# Print the optimal value of Alpha for Ridge Regression
print('Optimal Alpha Value: ', rregcv.alpha_)

# Print the RMSE for the ridge regression model
preds = rregcv.predict(X_test)
print ('RMSE (Ridge CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# Optimal Alpha Value:  0.1
# RMSE (Ridge CV reg.) = 3.05787802806

# %%
# lasso (alpha must be positive, larger means more regularization)
from sklearn.linear_model import Lasso
las = Lasso(alpha=0.01, normalize=True)
las.fit(X_train, y_train)
las.coef_
preds = las.predict(X_test)
print('RMSE (Lasso reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso reg.) = 3.06368768979

# %%
# try a smaller alpha
las = Lasso(alpha=0.001, normalize=True)
las.fit(X_train, y_train)
las.coef_
preds = las.predict(X_test)
print('RMSE (Lasso reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# RMSE (Lasso reg.) = 3.07911274596

# %%
a = 0.3
for name,met in [
        ('linear regression', LinearRegression()),
        ('lasso', Lasso(fit_intercept=True, alpha=a)),
        ('ridge', Ridge(fit_intercept=True, alpha=a)),
        ('elastic-net', ElasticNet(fit_intercept=True, alpha=a))
        ]:
    met.fit(x,y)
    #### p = np.array([met.predict(xi) for xi in x])
    p = met.predict(x)
    e = p-y
    total_error = np.dot(e,e)
    rmse_train = np.sqrt(total_error/len(p))

    kf = KFold(len(x), n_folds=10)
    err = 0
    for train,test in kf:
        met.fit(x[train],y[train])
        p = met.predict(x[test])
        e = p-y[test]
        err += np.dot(e,e)

    rmse_10cv = np.sqrt(err/len(x))
    print('Method: %s' %name)
    print('RMSE on training: %.4f' %rmse_train)
    print('RMSE on 10-fold CV: %.4f' %rmse_10cv)
    print "\n"

# %% [markdown]
# ### found this at
# ####  http://facweb.cs.depaul.edu/mobasher/classes/CSC478/Notes/IPython%20Notebook%20-%20Regression.html
#
# a = 0.3
# for name,met in [
#         ('linear regression', LinearRegression()),
#         ('lasso', Lasso(fit_intercept=True, alpha=a)),
#         ('ridge', Ridge(fit_intercept=True, alpha=a)),
#         ('elastic-net', ElasticNet(fit_intercept=True, alpha=a))
#         ]:
#     met.fit(x,y)
#     #### p = np.array([met.predict(xi) for xi in x])
#     p = met.predict(x)
#     e = p-y
#     total_error = np.dot(e,e)
#     rmse_train = np.sqrt(total_error/len(p))
#
#     kf = KFold(len(x), n_folds=10)
#     err = 0
#     for train,test in kf:
#         met.fit(x[train],y[train])
#         p = met.predict(x[test])
#         e = p-y[test]
#         err += np.dot(e,e)
#
#     rmse_10cv = np.sqrt(err/len(x))
#     print('Method: %s' %name)
#     print('RMSE on training: %.4f' %rmse_train)
#     print('RMSE on 10-fold CV: %.4f' %rmse_10cv)
#     print "\n"

# %%
from sklearn import cross_validation
kf = cross_validation.KFold(len(studentmath_with_dummies), n_folds=5, shuffle=True)

# %%
# cross
from sklearn import linear_model 
mse_values = []
scores = []
n= 0
print("~~~~ CROSS VALIDATION each fold ~~~~")
for train_index, test_index in kf:
    lm = linear_model.LinearRegression().fit(studentmath_with_dummies.iloc[train_index], y.iloc[train_index])
    mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(modeldata.iloc[test_index])))
    scores.append(lm.score(modeldata, y))
    n+=1
    print ('Model', n)
    print ('MSE:', mse_values[n-1])
    print ('R2:', scores[n-1])


print ("~~~~ SUMMARY OF CROSS VALIDATION ~~~~")
print ('Mean of MSE for all folds:', np.mean(mse_values))
print ('Mean of R2 for all folds:', np.mean(scores))

# %%
# allow plots to appear in the notebook
# %matplotlib inline
sns.lmplot(x='Medu', y='roundedAvg', data=studentmath, ci=None, fit_reg=False)
#  next two commands limit scales, comment out so you can see difference, my notes
sns.plt.xlim(-1, 6)
sns.plt.ylim(0, 20)

# %%
# ian said to try lasso
